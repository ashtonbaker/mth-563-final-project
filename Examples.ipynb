# %%
# %matplotlib inline

# %%
import music
import midi
import os

# %%
files = os.listdir('./midi')
songs = {}
for a in files:
    songs.update({a[:-4]:music.midi_import('./midi/' + a)})

# %%
range = [0, 200]
music.explore(songs['bwv529-1'], songs['bwv529-1'], 0, [0, 200], [0, 200]);
music.identify_runs(
    music.comparison_matrix(songs['bwv529-1'], songs['bwv529-1'],
        [0,200], [0,200]),
    0, 10, True);
